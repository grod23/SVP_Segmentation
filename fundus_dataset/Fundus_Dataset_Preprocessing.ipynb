# %%
import sys
import os
from pathlib import Path
import json
import joblib
import pandas as pd

# %% [markdown]
# # Root Dataset

# %%
root_path = r"C:\Users\gabe7\Downloads\Fundus_Dataset"

# %% [markdown]
# **Move all video paths into one list**

# %%
# Seperate training videos from labels
training_dirs = []
for dir in os.listdir(root_path):
    dir_path = os.path.join(root_path, dir)
    training_dirs.append(dir_path)

# Label directory is first item
label_dir = training_dirs.pop(0)

# %%
training_videos = []
for video_dir in training_dirs:
    # Each directory has 1 more directory to enter then videos
    inner_dir = os.listdir(video_dir)[0]
    video_dir_path = os.path.join(video_dir, inner_dir)
    for video_file in os.listdir(video_dir_path):
        # Full video file path
        video_path = os.path.join(video_dir_path, video_file)
        # Aggregate all video paths into 1 list
        training_videos.append(video_path)

# %% [markdown]
# **Labels**
# - Want peak and trough mask per SVP present video
# - Start and end frames of pulsations, may be multiple per video
# - Images of peak and trough frames

# %%
# JSON Files
disease_path = r"C:\Users\gabe7\Downloads\Fundus_Dataset\Labels\video_information\disease.json"
disease_variety_path = r"C:\Users\gabe7\Downloads\Fundus_Dataset\Labels\video_information\disease_variety.json"
temporal_localization_path = r"C:\Users\gabe7\Downloads\Fundus_Dataset\Labels\Temporal\Temporal_Localization\Temporal_localization.json"
peak_trough_metadata_path = r"C:\Users\gabe7\Downloads\Fundus_Dataset\Labels\Temporal\Peak_and_trough\Metadata.json"
training_path = r"C:\Users\gabe7\Downloads\Fundus_Dataset\Labels\Spatial\metadata\training.json"
validation_path = r"C:\Users\gabe7\Downloads\Fundus_Dataset\Labels\Spatial\metadata\validation.json"
testing_path = r"C:\Users\gabe7\Downloads\Fundus_Dataset\Labels\Spatial\metadata\testing.json"
svp_classification_path = r"C:\Users\gabe7\Downloads\Fundus_Dataset\Labels\Temporal\SVP_Classification\SVP_classification.json"

# %%
# SVP Classification
with open(svp_classification_path, 'r') as f:
    svp_classification = json.load(f)
svp_classification
# Out:
# {'0001.avi': 0,
#  '0002.avi': 1,
#  '0003.avi': 0,
#  '0004.avi': 0,
#  '0005.avi': 1,
#  '0006.avi': 0,
#  '0007.avi': 0,
#  '0008.avi': 0,
#  '0009.avi': 1,
#  '0010.avi': 1,
#  '0011.avi': 1,
#  '0012.avi': 0,
#  '0013.avi': 1,
#  '0014.avi': 1,
#  '0015.avi': 0,
#  '0016.avi': 1,
#  '0017.avi': 0,
#  '0018.avi': 0,
#  '0019.avi': 1,
#  '0020.avi': 1,
#  '0021.avi': 0,
#  '0022.avi': 1,
#  '0023.avi': 1,
#  '0024.avi': 0,
#  '0025.avi': 1,
#  '0026.avi': 0,
#  '0027.avi': 1,
#  '0028.avi': 1,
#  '0029.avi': 0,
#  '0030.avi': 0,
#  '0031.avi': 1,
#  '0032.avi': 1,
#  '0033.avi': 0,
#  '0034.avi': 0,
#  '0035.avi': 0,
#  '0036.avi': 0,
#  '0037.avi': 0,
#  '0038.avi': 0,
#  '0039.avi': 1,
#  '0040.avi': 0,
#  '0041.avi': 1,
#  '0042.avi': 0,
#  '0043.avi': 0,
#  '0044.avi': 0,
#  '0045.avi': 0,
#  '0046.avi': 0,
#  '0047.avi': 0,
#  '0048.avi': 1,
#  '0049.avi': 0,
#  '0050.avi': 1,
#  '0051.avi': 1,
#  '0052.avi': 1,
#  '0053.avi': 0,
#  '0054.avi': 1,
#  '0055.avi': 1,
#  '0056.avi': 1,
#  '0057.avi': 1,
#  '0058.avi': 1,
#  '0059.avi': 1,
#  '0060.avi': 1,
#  '0061.avi': 0,
#  '0062.avi': 1,
#  '0063.avi': 0,
#  '0064.avi': 1,
#  '0065.avi': 1,
#  '0066.avi': 1,
#  '0067.avi': 1,
#  '0068.avi': 0,
#  '0069.avi': 0,
#  '0070.avi': 0,
#  '0071.avi': 1,
#  '0072.avi': 1,
#  '0073.avi': 0,
#  '0074.avi': 1,
#  '0075.avi': 0,
#  '0076.avi': 0,
#  '0077.avi': 1,
#  '0078.avi': 0,
#  '0079.avi': 1,
#  '0080.avi': 1,
#  '0081.avi': 1,
#  '0082.avi': 0,
#  '0083.avi': 0,
#  '0084.avi': 1,
#  '0085.avi': 0,
#  '0086.avi': 0,
#  '0087.avi': 0,
#  '0088.avi': 0,
#  '0089.avi': 0,
#  '0090.avi': 0,
#  '0091.avi': 1,
#  '0092.avi': 1,
#  '0093.avi': 1,
#  '0094.avi': 1,
#  '0095.avi': 0,
#  '0096.avi': 1,
#  '0097.avi': 1,
#  '0098.avi': 1,
#  '0099.avi': 1,
#  '0100.avi': 1,
#  '0101.avi': 0,
#  '0102.avi': 0,
#  '0103.avi': 0,
#  '0104.avi': 0,
#  '0105.avi': 1,
#  '0106.avi': 1,
#  '0107.avi': 1,
#  '0108.avi': 1,
#  '0109.avi': 1,
#  '0110.avi': 1,
#  '0111.avi': 0,
#  '0112.avi': 1,
#  '0113.avi': 1,
#  '0114.avi': 1,
#  '0115.avi': 0,
#  '0116.avi': 0,
#  '0117.avi': 0,
#  '0118.avi': 0,
#  '0119.avi': 0,
#  '0120.avi': 1,
#  '0121.avi': 1,
#  '0122.avi': 1,
#  '0123.avi': 1,
#  '0124.avi': 1,
#  '0125.avi': 1,
#  '0126.avi': 1,
#  '0127.avi': 0,
#  '0128.avi': 1,
#  '0129.avi': 0,
#  '0130.avi': 1,
#  '0131.avi': 0,
#  '0132.avi': 0,
#  '0133.avi': 1,
#  '0134.avi': 1,
#  '0135.avi': 1,
#  '0136.avi': 1,
#  '0137.avi': 0,
#  '0138.avi': 1,
#  '0139.avi': 1,
#  '0140.avi': 1,
#  '0141.avi': 1,
#  '0142.avi': 0,
#  '0143.avi': 0,
#  '0144.avi': 0,
#  '0145.avi': 0,
#  '0146.avi': 0,
#  '0147.avi': 1,
#  '0148.avi': 0,
#  '0149.avi': 1,
#  '0150.avi': 1,
#  '0151.avi': 1,
#  '0152.avi': 1,
#  '0153.avi': 1,
#  '0154.avi': 0,
#  '0155.avi': 0,
#  '0156.avi': 0,
#  '0157.avi': 1,
#  '0158.avi': 1,
#  '0159.avi': 1,
#  '0160.avi': 1,
#  '0161.avi': 1,
#  '0162.avi': 0,
#  '0163.avi': 0,
#  '0164.avi': 1,
#  '0165.avi': 1,
#  '0166.avi': 1,
#  '0167.avi': 1,
#  '0168.avi': 1,
#  '0169.avi': 1,
#  '0170.avi': 0,
#  '0171.avi': 1,
#  '0172.avi': 1,
#  '0173.avi': 1,
#  '0174.avi': 1,
#  '0175.avi': 1,
#  '0176.avi': 1,
#  '0177.avi': 0,
#  '0178.avi': 1,
#  '0179.avi': 1,
#  '0180.avi': 1,
#  '0181.avi': 1,
#  '0182.avi': 1,
#  '0183.avi': 0,
#  '0184.avi': 1,
#  '0185.avi': 1,
#  '0186.avi': 1,
#  '0187.avi': 0,
#  '0188.avi': 0,
#  '0189.avi': 0,
#  '0190.avi': 0,
#  '0191.avi': 1,
#  '0192.avi': 0,
#  '0193.avi': 1,
#  '0194.avi': 0,
#  '0195.avi': 0,
#  '0196.avi': 1,
#  '0197.avi': 0,
#  '0198.avi': 1,
#  '0199.avi': 1,
#  '0200.avi': 1,
#  '0201.avi': 1,
#  '0202.avi': 1,
#  '0203.avi': 1,
#  '0204.avi': 1,
#  '0205.avi': 0,
#  '0206.avi': 1,
#  '0207.avi': 1,
#  '0208.avi': 1,
#  '0209.avi': 0,
#  '0210.avi': 1,
#  '0211.avi': 1,
#  '0212.avi': 0,
#  '0213.avi': 0,
#  '0214.avi': 1,
#  '0215.avi': 1,
#  '0216.avi': 1,
#  '0217.avi': 1,
#  '0218.avi': 1,
#  '0219.avi': 1,
#  '0220.avi': 0,
#  '0221.avi': 0,
#  '0222.avi': 0,
#  '0223.avi': 1,
#  '0224.avi': 1,
#  '0225.avi': 1,
#  '0226.avi': 1,
#  '0227.avi': 1,
#  '0228.avi': 1,
#  '0229.avi': 1,
#  '0230.avi': 1,
#  '0231.avi': 0,
#  '0232.avi': 0,
#  '0233.avi': 0,
#  '0234.avi': 1,
#  '0235.avi': 1,
#  '0236.avi': 0,
#  '0237.avi': 0,
#  '0238.avi': 0,
#  '0239.avi': 0,
#  '0240.avi': 0,
#  '0241.avi': 1,
#  '0242.avi': 1,
#  '0243.avi': 0,
#  '0244.avi': 1,
#  '0245.avi': 1,
#  '0246.avi': 1,
#  '0247.avi': 1,
#  '0248.avi': 0,
#  '0249.avi': 1,
#  '0250.avi': 1,
#  '0251.avi': 0,
#  '0252.avi': 1,
#  '0253.avi': 1,
#  '0254.avi': 0,
#  '0255.avi': 0,
#  '0256.avi': 1,
#  '0257.avi': 0,
#  '0258.avi': 0,
#  '0259.avi': 0,
#  '0260.avi': 1,
#  '0261.avi': 1,
#  '0262.avi': 0,
#  '0263.avi': 1,
#  '0264.avi': 1,
#  '0265.avi': 1,
#  '0266.avi': 0,
#  '0267.avi': 1,
#  '0268.avi': 1,
#  '0269.avi': 1,
#  '0270.avi': 1,
#  '0271.avi': 1,
#  '0272.avi': 0,
#  '0273.avi': 0,
#  '0274.avi': 0,
#  '0275.avi': 1,
#  '0276.avi': 1,
#  '0277.avi': 1,
#  '0278.avi': 1,
#  '0279.avi': 0,
#  '0280.avi': 0,
#  '0281.avi': 1,
#  '0282.avi': 0,
#  '0283.avi': 0,
#  '0284.avi': 0,
#  '0285.avi': 1,
#  '0286.avi': 1,
#  '0287.avi': 0,
#  '0288.avi': 0,
#  '0289.avi': 0,
#  '0290.avi': 1,
#  '0291.avi': 1,
#  '0292.avi': 1,
#  '0293.avi': 1,
#  '0294.avi': 1,
#  '0295.avi': 0,
#  '0296.avi': 0,
#  '0297.avi': 0,
#  '0298.avi': 0,
#  '0299.avi': 1,
#  '0300.avi': 0,
#  '0301.avi': 0,
#  '0302.avi': 1,
#  '0303.avi': 1,
#  '0304.avi': 1,
#  '0305.avi': 1,
#  '0306.avi': 0,
#  '0307.avi': 1,
#  '0308.avi': 1,
#  '0309.avi': 1,
#  '0310.avi': 1,
#  '0311.avi': 0,
#  '0312.avi': 1,
#  '0313.avi': 0,
#  '0314.avi': 1,
#  '0315.avi': 0,
#  '0316.avi': 0,
#  '0317.avi': 1,
#  '0318.avi': 1,
#  '0319.avi': 0,
#  '0320.avi': 0,
#  '0321.avi': 1,
#  '0322.avi': 1,
#  '0323.avi': 1,
#  '0324.avi': 0,
#  '0325.avi': 0,
#  '0326.avi': 0,
#  '0327.avi': 0,
#  '0328.avi': 1,
#  '0329.avi': 1,
#  '0330.avi': 0,
#  '0331.avi': 1,
#  '0332.avi': 1,
#  '0333.avi': 0,
#  '0334.avi': 0,
#  '0335.avi': 0,
#  '0336.avi': 1,
#  '0337.avi': 1,
#  '0338.avi': 0,
#  '0339.avi': 0,
#  '0340.avi': 0,
#  '0341.avi': 1,
#  '0342.avi': 1,
#  '0343.avi': 0,
#  '0344.avi': 0,
#  '0345.avi': 0,
#  '0346.avi': 1,
#  '0347.avi': 0,
#  '0348.avi': 0,
#  '0349.avi': 0,
#  '0350.avi': 0,
#  '0351.avi': 0,
#  '0352.avi': 0,
#  '0353.avi': 1,
#  '0354.avi': 1,
#  '0355.avi': 1,
#  '0356.avi': 0,
#  '0357.avi': 1,
#  '0358.avi': 0,
#  '0359.avi': 1,
#  '0360.avi': 0,
#  '0361.avi': 1,
#  '0362.avi': 0,
#  '0363.avi': 0,
#  '1001.avi': 0,
#  '1002.avi': 0,
#  '1003.avi': 0,
#  '1004.avi': 0,
#  '1005.avi': 0,
#  '1006.avi': 0,
#  '1007.avi': 1,
#  '1009.avi': 1,
#  '1011.avi': 1,
#  '1012.avi': 1,
#  '1013.avi': 0,
#  '1014.avi': 0,
#  '1015.avi': 0,
#  '1016.avi': 0,
#  '1017.avi': 0,
#  '1018.avi': 1,
#  '1019.avi': 0,
#  '1021.avi': 1,
#  '1022.avi': 1,
#  '1023.avi': 0,
#  '1024.avi': 0,
#  '1025.avi': 0,
#  '1026.avi': 0,
#  '1027.avi': 0,
#  '1028.avi': 0,
#  '1029.avi': 0,
#  '1030.avi': 1,
#  '1031.avi': 0,
#  '1032.avi': 0,
#  '1034.avi': 1,
#  '1035.avi': 0,
#  '1036.avi': 0,
#  '1040.avi': 0,
#  '1042.avi': 0,
#  '1043.avi': 1,
#  '1044.avi': 0,
#  '1045.avi': 0,
#  '1046.avi': 1,
#  '1047.avi': 0,
#  '1048.avi': 0,
#  '1049.avi': 0,
#  '1050.avi': 1,
#  '1052.avi': 0,
#  '1053.avi': 0,
#  '1054.avi': 1,
#  '1055.avi': 0,
#  '1056.avi': 0,
#  '1057.avi': 0,
#  '1058.avi': 0,
#  '1059.avi': 1,
#  '1060.avi': 1,
#  '1061.avi': 0,
#  '1062.avi': 1,
#  '1063.avi': 0,
#  '1064.avi': 1,
#  '1065.avi': 1,
#  '1066.avi': 1,
#  '1067.avi': 1,
#  '1068.avi': 0,
#  '1069.avi': 1,
#  '1070.avi': 1,
#  '1071.avi': 1,
#  '1072.avi': 0,
#  '1073.avi': 0,
#  '1074.avi': 1,
#  '1075.avi': 1,
#  '1076.avi': 0,
#  '1077.avi': 0,
#  '1078.avi': 0,
#  '1079.avi': 0,
#  '1080.avi': 0,
#  '1081.avi': 1,
#  '1082.avi': 0,
#  '1083.avi': 0,
#  '1084.avi': 1,
#  '1085.avi': 1,
#  '1086.avi': 1,
#  '1087.avi': 0,
#  '1088.avi': 1,
#  '1089.avi': 1,
#  '1090.avi': 0,
#  '1091.avi': 0,
#  '1092.avi': 1,
#  '1093.avi': 1,
#  '1094.avi': 1,
#  '1095.avi': 1,
#  '1096.avi': 1,
#  '1097.avi': 0,
#  '1098.avi': 0,
#  '1099.avi': 0,
#  '1100.avi': 0,
#  '1101.avi': 1,
#  '1102.avi': 1,
#  '1103.avi': 0,
#  '1104.avi': 0,
#  '1105.avi': 1,
#  '1106.avi': 1,
#  '1107.avi': 0,
#  '1108.avi': 0,
#  '1109.avi': 0,
#  '1110.avi': 0,
#  '1111.avi': 0,
#  '1112.avi': 0,
#  '1113.avi': 1,
#  '1114.avi': 0,
#  '1115.avi': 0,
#  '1117.avi': 0,
#  '1118.avi': 0,
#  '1119.avi': 0,
#  '1120.avi': 0,
#  '1121.avi': 0,
#  '1122.avi': 1,
#  '1123.avi': 1,
#  '1124.avi': 0,
#  '1125.avi': 1,
#  '1126.avi': 0,
#  '1127.avi': 1,
#  '1128.avi': 0,
#  '1129.avi': 0,
#  '1130.avi': 0,
#  '1131.avi': 0,
#  '1132.avi': 1,
#  '1133.avi': 0,
#  '1134.avi': 0,
#  '1135.avi': 1,
#  '1136.avi': 0,
#  '1137.avi': 1,
#  '1138.avi': 0,
#  '1139.avi': 0,
#  '1140.avi': 1,
#  '1141.avi': 1,
#  '1142.avi': 0,
#  '1143.avi': 1,
#  '1144.avi': 1,
#  '1145.avi': 0,
#  '1146.avi': 0,
#  '1147.avi': 0,
#  '1148.avi': 0,
#  '1149.avi': 1,
#  '1150.avi': 0,
#  '1151.avi': 1,
#  '1152.avi': 1,
#  '1153.avi': 0,
#  '1154.avi': 0,
#  '1155.avi': 0,
#  '1156.avi': 1,
#  '1157.avi': 1,
#  '1158.avi': 1,
#  '1159.avi': 0,
#  '1160.avi': 1,
#  '1161.avi': 1,
#  '1162.avi': 1,
#  '1163.avi': 1,
#  '1164.avi': 0,
#  '1165.avi': 1,
#  '1166.avi': 0,
#  '1167.avi': 1,
#  '1168.avi': 1,
#  '1169.avi': 1,
#  '1170.avi': 1,
#  '1171.avi': 1,
#  '1172.avi': 0,
#  '1173.avi': 0,
#  '1174.avi': 1,
#  '1175.avi': 0,
#  '1176.avi': 0,
#  '1177.avi': 0,
#  '1178.avi': 1,
#  '1179.avi': 1,
#  '1180.avi': 1,
#  '1181.avi': 0,
#  '1182.avi': 0,
#  '1183.avi': 1,
#  '1184.avi': 1,
#  '1185.avi': 1,
#  '1186.avi': 1,
#  '1188.avi': 1,
#  '1189.avi': 1,
#  '1190.avi': 1,
#  '1191.avi': 1,
#  '1192.avi': 0,
#  '1193.avi': 1,
#  '1194.avi': 0,
#  '1195.avi': 0,
#  '1196.avi': 0,
#  '1197.avi': 1,
#  '1198.avi': 1,
#  '1199.avi': 1,
#  '1200.avi': 1,
#  '1201.avi': 1,
#  '1202.avi': 0,
#  '1203.avi': 0,
#  '1204.avi': 1,
#  '1205.avi': 1,
#  '1206.avi': 1,
#  '1207.avi': 1,
#  '1208.avi': 0,
#  '1209.avi': 0,
#  '1210.avi': 0,
#  '1211.avi': 1,
#  '1212.avi': 1,
#  '1213.avi': 1,
#  '1214.avi': 1,
#  '1215.avi': 1,
#  '1216.avi': 1,
#  '1217.avi': 1,
#  '1218.avi': 1,
#  '1219.avi': 1,
#  '1220.avi': 0,
#  '1221.avi': 0,
#  '1222.avi': 0,
#  '1223.avi': 1,
#  '1224.avi': 0,
#  '1225.avi': 1,
#  '1226.avi': 1,
#  '1227.avi': 0,
#  '1228.avi': 1,
#  '1229.avi': 1,
#  '1230.avi': 0,
#  '1231.avi': 0,
#  '1232.avi': 1,
#  '1233.avi': 1,
#  '1234.avi': 0,
#  '1235.avi': 1,
#  '1236.avi': 0,
#  '1237.avi': 0,
#  '1238.avi': 0,
#  '1239.avi': 0,
#  '1240.avi': 0,
#  '1241.avi': 0,
#  '1242.avi': 0,
#  '1243.avi': 0,
#  '1244.avi': 1,
#  '1245.avi': 0,
#  '1246.avi': 0,
#  '1247.avi': 0,
#  '1248.avi': 1,
#  '1249.avi': 1,
#  '1250.avi': 1,
#  '1251.avi': 0,
#  '1252.avi': 1,
#  '1253.avi': 1,
#  '1254.avi': 0,
#  '1255.avi': 1,
#  '1256.avi': 1,
#  '1257.avi': 0,
#  '1258.avi': 1,
#  '1259.avi': 0,
#  '1260.avi': 0,
#  '1261.avi': 1,
#  '1262.avi': 1,
#  '1263.avi': 0,
#  '1264.avi': 0,
#  '1265.avi': 0,
#  '1266.avi': 0,
#  '1267.avi': 1,
#  '1268.avi': 1,
#  '1269.avi': 0,
#  '1270.avi': 0,
#  '1271.avi': 1,
#  '1272.avi': 1,
#  '1273.avi': 0,
#  '1274.avi': 1,
#  '1275.avi': 1,
#  '1276.avi': 1,
#  '1277.avi': 1,
#  '1278.avi': 1,
#  '1279.avi': 1,
#  '1280.avi': 0,
#  '1281.avi': 1,
#  '1282.avi': 1,
#  '1283.avi': 1}

# %%
# Disease Variety
with open(disease_variety_path, 'r') as f:
    disease_variety = json.load(f)
disease_variety
# Out:
# {'0001': ['Glaucoma-present', 'svp-absent'],
#  '0002': ['Glaucoma-present', 'svp-present'],
#  '0003': ['Normal'],
#  '0004': ['Normal'],
#  '0005': ['Glaucoma-present', 'svp-present'],
#  '0006': ['Glaucoma-present', 'svp-absent'],
#  '0007': ['Glaucoma-present', 'svp-absent'],
#  '0008': ['Glaucoma-present', 'svp-absent'],
#  '0013': ['Normal'],
#  '0014': ['Normal'],
#  '0017': ['Normal'],
#  '0018': ['Normal'],
#  '0021': ['Glaucoma-present', 'svp-absent'],
#  '0023': ['Normal'],
#  '0025': ['Glaucoma-present', 'svp-present'],
#  '0029': ['Normal'],
#  '0031': ['Glaucoma-present', 'svp-present'],
#  '0033': ['Normal'],
#  '0039': ['Glaucoma-present', 'svp-present'],
#  '0041': ['Glaucoma-present', 'svp-present'],
#  '0045': ['Glaucoma-present', 'svp-absent'],
#  '0047': ['Glaucoma-present', 'svp-absent'],
#  '0049': ['Glaucoma-present', 'svp-absent'],
#  '0053': ['Glaucoma-present', 'svp-absent'],
#  '0061': ['Glaucoma-present', 'svp-absent'],
#  '0063': ['Normal'],
#  '0067': ['Normal'],
#  '0068': ['Normal'],
#  '0069': ['Glaucoma-present', 'svp-absent'],
#  '0070': ['Glaucoma-present', 'svp-absent'],
#  '0071': ['Normal'],
#  '0072': ['Normal'],
#  '0073': ['Glaucoma-present', 'svp-absent'],
#  '0074': ['Glaucoma-present', 'svp-present'],
#  '0077': ['Normal'],
#  '0078': ['Normal'],
#  '0079': ['Glaucoma-present', 'svp-present'],
#  '0080': ['Glaucoma-present', 'svp-present'],
#  '0081': ['Glaucoma-present', 'svp-present'],
#  '0082': ['Glaucoma-present', 'svp-absent'],
#  '0083': ['Glaucoma-present', 'svp-absent'],
#  '0084': ['Glaucoma-present', 'svp-present'],
#  '0086': ['Glaucoma-present', 'svp-absent'],
#  '0088': ['Glaucoma-present', 'svp-absent'],
#  '0089': ['Glaucoma-present', 'svp-absent'],
#  '0090': ['Glaucoma-present', 'svp-absent'],
#  '0092': ['Glaucoma-present', 'svp-present'],
#  '0093': ['Glaucoma-present', 'svp-present'],
#  '0094': ['Glaucoma-present', 'svp-present'],
#  '0095': ['Glaucoma-present', 'svp-absent'],
#  '0096': ['Glaucoma-present', 'svp-present'],
#  '0097': ['Glaucoma-present', 'svp-present'],
#  '0098': ['Glaucoma-present', 'svp-present'],
#  '0099': ['Normal'],
#  '0100': ['Normal'],
#  '0104': ['Glaucoma-present', 'svp-absent'],
#  '0105': ['Glaucoma-present', 'svp-present'],
#  '0106': ['Normal'],
#  '0107': ['Normal'],
#  '0108': ['Normal'],
#  '0109': ['Normal'],
#  '0110': ['Normal'],
#  '0111': ['Normal'],
#  '0112': ['Normal'],
#  '0113': ['Normal'],
#  '0114': ['Normal'],
#  '0116': ['Glaucoma-present', 'svp-absent'],
#  '0117': ['Glaucoma-present', 'svp-absent'],
#  '0118': ['Glaucoma-present', 'svp-absent'],
#  '0119': ['Glaucoma-present', 'svp-absent'],
#  '0120': ['Normal'],
#  '0121': ['Normal'],
#  '0122': ['Normal'],
#  '0123': ['Normal'],
#  '0124': ['Glaucoma-present', 'svp-present'],
#  '0125': ['Glaucoma-present', 'svp-present'],
#  '0126': ['Normal'],
#  '0127': ['Normal'],
#  '0128': ['Glaucoma-present', 'svp-present'],
#  '0129': ['Glaucoma-present', 'svp-absent'],
#  '0130': ['Glaucoma-present', 'svp-present'],
#  '0131': ['Glaucoma-present', 'svp-absent'],
#  '0132': ['Glaucoma-present', 'svp-absent'],
#  '0133': ['Glaucoma-present', 'svp-present'],
#  '0134': ['Glaucoma-present', 'svp-present'],
#  '0135': ['Glaucoma-present', 'svp-present'],
#  '0136': ['Glaucoma-present', 'svp-present'],
#  '0137': ['Glaucoma-present', 'svp-absent'],
#  '0138': ['Glaucoma-present', 'svp-present'],
#  '0139': ['Glaucoma-present', 'svp-present'],
#  '0140': ['Glaucoma-present', 'svp-present'],
#  '0141': ['Glaucoma-present', 'svp-present'],
#  '0143': ['Glaucoma-present', 'svp-absent'],
#  '0144': ['Glaucoma-present', 'svp-absent'],
#  '0146': ['Normal'],
#  '0148': ['Glaucoma-present', 'svp-absent'],
#  '0150': ['Glaucoma-present', 'svp-present'],
#  '0152': ['Glaucoma-present', 'svp-present'],
#  '0153': ['Glaucoma-present', 'svp-present'],
#  '0154': ['Glaucoma-present', 'svp-absent'],
#  '0156': ['Normal'],
#  '0158': ['Glaucoma-present', 'svp-present'],
#  '0159': ['Glaucoma-present', 'svp-present'],
#  '0160': ['Glaucoma-present', 'svp-present'],
#  '0162': ['Glaucoma-present', 'svp-absent'],
#  '0163': ['Glaucoma-present', 'svp-absent'],
#  '0164': ['Glaucoma-present', 'svp-present'],
#  '0166': ['Glaucoma-present', 'svp-present'],
#  '0168': ['Normal'],
#  '0170': ['Glaucoma-present', 'svp-absent'],
#  '0171': ['Glaucoma-present', 'svp-present'],
#  '0172': ['Glaucoma-present', 'svp-present'],
#  '0173': ['Glaucoma-present', 'svp-present'],
#  '0174': ['Normal'],
#  '0184': ['Normal'],
#  '0185': ['Glaucoma-present', 'svp-present'],
#  '0189': ['Glaucoma-present', 'svp-absent'],
#  '0191': ['Normal'],
#  '0195': ['Glaucoma-present', 'svp-absent'],
#  '0201': ['Glaucoma-present', 'svp-present'],
#  '0205': ['Glaucoma-present', 'svp-absent'],
#  '0207': ['Normal'],
#  '0209': ['Glaucoma-present', 'svp-absent'],
#  '0210': ['Normal'],
#  '0212': ['Normal'],
#  '0214': ['Normal'],
#  '0216': ['Glaucoma-present', 'svp-present'],
#  '0218': ['Normal'],
#  '0220': ['Normal'],
#  '0222': ['Normal'],
#  '0223': ['Normal'],
#  '0225': ['Normal'],
#  '0227': ['Normal'],
#  '0229': ['Normal'],
#  '0232': ['Normal'],
#  '0234': ['Normal'],
#  '0244': ['Normal'],
#  '0246': ['Normal'],
#  '0248': ['Normal'],
#  '0249': ['Glaucoma-present', 'svp-present'],
#  '0251': ['Normal'],
#  '0254': ['Glaucoma-present', 'svp-absent'],
#  '0256': ['Normal'],
#  '0258': ['Normal'],
#  '0260': ['Normal'],
#  '0263': ['Normal'],
#  '0265': ['Glaucoma-present', 'svp-present'],
#  '0267': ['Glaucoma-present', 'svp-present'],
#  '0269': ['Glaucoma-present', 'svp-present'],
#  '0271': ['Glaucoma-present', 'svp-present'],
#  '0273': ['Normal'],
#  '0274': ['Normal'],
#  '0280': ['Glaucoma-present', 'svp-absent'],
#  '0282': ['Normal'],
#  '0283': ['Normal'],
#  '0284': ['Normal'],
#  '0285': ['Normal'],
#  '0286': ['Glaucoma-present', 'svp-present'],
#  '0287': ['Glaucoma-present', 'svp-absent'],
#  '0288': ['Normal'],
#  '0289': ['Normal'],
#  '0290': ['Glaucoma-present', 'svp-present'],
#  '0291': ['Glaucoma-present', 'svp-present'],
#  '0292': ['Glaucoma-present', 'svp-present'],
#  '0293': ['Glaucoma-present', 'svp-present'],
#  '0297': ['Glaucoma-present', 'svp-absent'],
#  '0298': ['Normal'],
#  '0300': ['Glaucoma-present', 'svp-absent'],
#  '0301': ['Glaucoma-present', 'svp-absent'],
#  '0304': ['Glaucoma-present', 'svp-present'],
#  '0305': ['Glaucoma-present', 'svp-present'],
#  '0306': ['Glaucoma-present', 'svp-absent'],
#  '0307': ['Normal'],
#  '0308': ['Normal'],
#  '0309': ['Normal'],
#  '0310': ['Normal'],
#  '0311': ['Normal'],
#  '0312': ['Normal'],
#  '0313': ['Glaucoma-present', 'svp-absent'],
#  '0314': ['Glaucoma-present', 'svp-present'],
#  '0315': ['Glaucoma-present', 'svp-absent'],
#  '0316': ['Glaucoma-present', 'svp-absent'],
#  '0317': ['Glaucoma-present', 'svp-present'],
#  '0318': ['Glaucoma-present', 'svp-present'],
#  '0324': ['Glaucoma-present', 'svp-absent'],
#  '0325': ['Glaucoma-present', 'svp-absent'],
#  '0328': ['Glaucoma-present', 'svp-present'],
#  '0329': ['Normal'],
#  '0331': ['Glaucoma-present', 'svp-present'],
#  '0332': ['Glaucoma-present', 'svp-present'],
#  '0333': ['Glaucoma-present', 'svp-absent'],
#  '0334': ['Glaucoma-present', 'svp-absent'],
#  '0336': ['Glaucoma-present', 'svp-present'],
#  '0338': ['Glaucoma-present', 'svp-absent'],
#  '0339': ['Glaucoma-present', 'svp-absent'],
#  '0340': ['Glaucoma-present', 'svp-absent'],
#  '0341': ['Glaucoma-present', 'svp-present'],
#  '0342': ['Glaucoma-present', 'svp-present'],
#  '0343': ['Glaucoma-present', 'svp-absent'],
#  '0345': ['Glaucoma-present', 'svp-absent'],
#  '0346': ['Glaucoma-present', 'svp-present'],
#  '0347': ['Glaucoma-present', 'svp-absent'],
#  '0348': ['Glaucoma-present', 'svp-absent'],
#  '0349': ['Glaucoma-present', 'svp-absent'],
#  '0350': ['Normal'],
#  '0351': ['Glaucoma-present', 'svp-absent'],
#  '0352': ['Glaucoma-present', 'svp-absent'],
#  '0353': ['Glaucoma-present', 'svp-present'],
#  '0354': ['Glaucoma-present', 'svp-present'],
#  '0355': ['Normal'],
#  '0356': ['Normal'],
#  '0357': ['Glaucoma-present', 'svp-present'],
#  '0358': ['Glaucoma-present', 'svp-absent'],
#  '0359': ['Glaucoma-present', 'svp-present'],
#  '0360': ['Glaucoma-present', 'svp-absent'],
#  '0361': ['Normal'],
#  '0362': ['Glaucoma-present', 'svp-absent'],
#  '0363': ['Normal'],
#  '1001': ['Glaucoma-present', 'svp-absent'],
#  '1002': ['Glaucoma-present', 'svp-absent'],
#  '1003': ['Glaucoma-present', 'svp-absent'],
#  '1004': ['Glaucoma-present', 'svp-absent'],
#  '1005': ['Normal'],
#  '1006': ['Glaucoma-present', 'svp-absent'],
#  '1007': ['Normal'],
#  '1009': ['Normal'],
#  '1011': ['Normal'],
#  '1012': ['Normal'],
#  '1013': ['Glaucoma-present', 'svp-absent'],
#  '1014': ['Glaucoma-present', 'svp-absent'],
#  '1015': ['Glaucoma-present', 'svp-absent'],
#  '1016': ['Glaucoma-present', 'svp-absent'],
#  '1017': ['Normal'],
#  '1018': ['Normal'],
#  '1019': ['Glaucoma-present', 'svp-absent'],
#  '1021': ['Normal'],
#  '1022': ['Normal'],
#  '1023': ['Normal'],
#  '1024': ['Glaucoma-present', 'svp-absent'],
#  '1025': ['Normal'],
#  '1026': ['Glaucoma-present', 'svp-absent'],
#  '1027': ['Glaucoma-present', 'svp-absent'],
#  '1028': ['Glaucoma-present', 'svp-absent'],
#  '1029': ['Glaucoma-present', 'svp-absent'],
#  '1030': ['Normal'],
#  '1031': ['Glaucoma-present', 'svp-absent'],
#  '1032': ['Glaucoma-present', 'svp-absent'],
#  '1034': ['Normal'],
#  '1035': ['Glaucoma-present', 'svp-absent'],
#  '1036': ['Glaucoma-present', 'svp-absent'],
#  '1040': ['Glaucoma-present', 'svp-absent'],
#  '1042': ['Glaucoma-present', 'svp-absent'],
#  '1043': ['Normal'],
#  '1044': ['Normal'],
#  '1045': ['Glaucoma-present', 'svp-absent'],
#  '1046': ['Glaucoma-present', 'svp-present'],
#  '1047': ['Normal'],
#  '1048': ['Normal'],
#  '1049': ['Normal'],
#  '1050': ['Normal'],
#  '1052': ['Glaucoma-present', 'svp-absent'],
#  '1053': ['Glaucoma-present', 'svp-absent'],
#  '1054': ['Normal'],
#  '1055': ['Glaucoma-present', 'svp-absent'],
#  '1056': ['Glaucoma-present', 'svp-absent'],
#  '1057': ['Glaucoma-present', 'svp-absent'],
#  '1058': ['Normal'],
#  '1059': ['Normal'],
#  '1060': ['Normal'],
#  '1061': ['Glaucoma-present', 'svp-absent'],
#  '1062': ['Normal'],
#  '1063': ['Glaucoma-present', 'svp-absent'],
#  '1064': ['Normal'],
#  '1065': ['Normal'],
#  '1066': ['Normal'],
#  '1067': ['Normal'],
#  '1068': ['Normal'],
#  '1069': ['Normal'],
#  '1070': ['Normal'],
#  '1071': ['Normal'],
#  '1072': ['Normal'],
#  '1073': ['Glaucoma-present', 'svp-absent'],
#  '1074': ['Normal'],
#  '1075': ['Normal'],
#  '1076': ['Glaucoma-present', 'svp-absent'],
#  '1077': ['Normal'],
#  '1078': ['Normal'],
#  '1079': ['Glaucoma-present', 'svp-absent'],
#  '1080': ['Glaucoma-present', 'svp-absent'],
#  '1081': ['Normal'],
#  '1082': ['Glaucoma-present', 'svp-absent'],
#  '1083': ['Normal'],
#  '1084': ['Normal'],
#  '1085': ['Normal'],
#  '1086': ['Normal'],
#  '1087': ['Glaucoma-present', 'svp-absent'],
#  '1088': ['Glaucoma-present', 'svp-present'],
#  '1089': ['Normal'],
#  '1090': ['Glaucoma-present', 'svp-absent'],
#  '1091': ['Glaucoma-present', 'svp-absent'],
#  '1092': ['Glaucoma-present', 'svp-present'],
#  '1093': ['Normal'],
#  '1094': ['Normal'],
#  '1095': ['Normal'],
#  '1096': ['Glaucoma-present', 'svp-present'],
#  '1097': ['Normal'],
#  '1098': ['Glaucoma-present', 'svp-absent'],
#  '1099': ['Normal'],
#  '1100': ['Normal'],
#  '1101': ['Normal'],
#  '1102': ['Normal'],
#  '1103': ['Glaucoma-present', 'svp-absent'],
#  '1104': ['Glaucoma-present', 'svp-absent'],
#  '1105': ['Normal'],
#  '1106': ['Normal'],
#  '1107': ['Glaucoma-present', 'svp-absent'],
#  '1108': ['Glaucoma-present', 'svp-absent'],
#  '1109': ['Glaucoma-present', 'svp-absent'],
#  '1110': ['Normal'],
#  '1111': ['Glaucoma-present', 'svp-absent'],
#  '1112': ['Normal'],
#  '1113': ['Glaucoma-present', 'svp-present'],
#  '1114': ['Glaucoma-present', 'svp-absent'],
#  '1115': ['Glaucoma-present', 'svp-absent'],
#  '1117': ['Glaucoma-present', 'svp-absent'],
#  '1118': ['Glaucoma-present', 'svp-absent'],
#  '1119': ['Glaucoma-present', 'svp-absent'],
#  '1120': ['Glaucoma-present', 'svp-absent'],
#  '1121': ['Glaucoma-present', 'svp-absent'],
#  '1122': ['Normal'],
#  '1123': ['Normal'],
#  '1124': ['Glaucoma-present', 'svp-absent'],
#  '1125': ['Glaucoma-present', 'svp-present'],
#  '1126': ['Normal'],
#  '1127': ['Glaucoma-present', 'svp-present'],
#  '1128': ['Normal'],
#  '1129': ['Normal'],
#  '1130': ['Glaucoma-present', 'svp-absent'],
#  '1131': ['Glaucoma-present', 'svp-absent'],
#  '1132': ['Normal'],
#  '1133': ['Glaucoma-present', 'svp-absent'],
#  '1134': ['Glaucoma-present', 'svp-absent'],
#  '1135': ['Glaucoma-present', 'svp-present'],
#  '1136': ['Glaucoma-present', 'svp-absent'],
#  '1137': ['Normal'],
#  '1138': ['Glaucoma-present', 'svp-absent'],
#  '1139': ['Glaucoma-present', 'svp-absent'],
#  '1140': ['Normal'],
#  '1141': ['Normal'],
#  '1142': ['Glaucoma-present', 'svp-absent'],
#  '1143': ['Glaucoma-present', 'svp-present'],
#  '1144': ['Normal'],
#  '1145': ['Glaucoma-present', 'svp-absent'],
#  '1146': ['Normal'],
#  '1147': ['Normal'],
#  '1148': ['Normal'],
#  '1149': ['Normal'],
#  '1150': ['Normal'],
#  '1151': ['Normal'],
#  '1152': ['Normal'],
#  '1153': ['Glaucoma-present', 'svp-absent'],
#  '1154': ['Glaucoma-present', 'svp-absent'],
#  '1155': ['Glaucoma-present', 'svp-absent'],
#  '1156': ['Normal'],
#  '1157': ['Normal'],
#  '1158': ['Normal'],
#  '1159': ['Glaucoma-present', 'svp-absent'],
#  '1160': ['Normal'],
#  '1161': ['Normal'],
#  '1162': ['Normal'],
#  '1163': ['Normal'],
#  '1164': ['Glaucoma-present', 'svp-absent'],
#  '1165': ['Normal'],
#  '1166': ['Glaucoma-present', 'svp-absent'],
#  '1167': ['Normal'],
#  '1168': ['Normal'],
#  '1169': ['Normal'],
#  '1170': ['Normal'],
#  '1171': ['Normal'],
#  '1172': ['Glaucoma-present', 'svp-absent'],
#  '1173': ['Normal'],
#  '1174': ['Normal'],
#  '1175': ['Glaucoma-present', 'svp-absent'],
#  '1176': ['Normal'],
#  '1177': ['Glaucoma-present', 'svp-absent'],
#  '1178': ['Normal'],
#  '1179': ['Normal'],
#  '1180': ['Normal'],
#  '1181': ['Glaucoma-present', 'svp-absent'],
#  '1182': ['Glaucoma-present', 'svp-absent'],
#  '1183': ['Normal'],
#  '1184': ['Normal'],
#  '1185': ['Normal'],
#  '1186': ['Normal'],
#  '1188': ['Normal'],
#  '1189': ['Normal'],
#  '1190': ['Normal'],
#  '1191': ['Normal'],
#  '1192': ['Glaucoma-present', 'svp-absent'],
#  '1193': ['Glaucoma-present', 'svp-present'],
#  '1194': ['Glaucoma-present', 'svp-absent'],
#  '1195': ['Glaucoma-present', 'svp-absent'],
#  '1196': ['Glaucoma-present', 'svp-absent'],
#  '1197': ['Normal'],
#  '1198': ['Normal'],
#  '1199': ['Normal'],
#  '1200': ['Glaucoma-present', 'svp-present'],
#  '1201': ['Glaucoma-present', 'svp-present'],
#  '1202': ['Glaucoma-present', 'svp-absent'],
#  '1203': ['Glaucoma-present', 'svp-absent'],
#  '1204': ['Normal'],
#  '1205': ['Normal'],
#  '1206': ['Normal'],
#  '1207': ['Normal'],
#  '1208': ['Glaucoma-present', 'svp-absent'],
#  '1209': ['Glaucoma-present', 'svp-absent'],
#  '1210': ['Glaucoma-present', 'svp-absent'],
#  '1211': ['Normal'],
#  '1212': ['Normal'],
#  '1213': ['Normal'],
#  '1214': ['Glaucoma-present', 'svp-present'],
#  '1215': ['Normal'],
#  '1216': ['Glaucoma-present', 'svp-present'],
#  '1217': ['Normal'],
#  '1218': ['Normal'],
#  '1219': ['Normal'],
#  '1220': ['Glaucoma-present', 'svp-absent'],
#  '1221': ['Glaucoma-present', 'svp-absent'],
#  '1222': ['Glaucoma-present', 'svp-absent'],
#  '1223': ['Normal'],
#  '1224': ['Glaucoma-present', 'svp-absent'],
#  '1225': ['Normal'],
#  '1226': ['Normal'],
#  '1227': ['Glaucoma-present', 'svp-absent'],
#  '1228': ['Normal'],
#  '1229': ['Normal'],
#  '1230': ['Glaucoma-present', 'svp-absent'],
#  '1231': ['Glaucoma-present', 'svp-absent'],
#  '1232': ['Normal'],
#  '1233': ['Normal'],
#  '1234': ['Normal'],
#  '1235': ['Normal'],
#  '1236': ['Normal'],
#  '1237': ['Normal'],
#  '1238': ['Glaucoma-present', 'svp-absent'],
#  '1239': ['Glaucoma-present', 'svp-absent'],
#  '1240': ['Glaucoma-present', 'svp-absent'],
#  '1241': ['Glaucoma-present', 'svp-absent'],
#  '1242': ['Glaucoma-present', 'svp-absent'],
#  '1243': ['Normal'],
#  '1244': ['Normal'],
#  '1245': ['Glaucoma-present', 'svp-absent'],
#  '1246': ['Normal'],
#  '1247': ['Glaucoma-present', 'svp-absent'],
#  '1248': ['Normal'],
#  '1249': ['Normal'],
#  '1250': ['Normal'],
#  '1251': ['Glaucoma-present', 'svp-absent'],
#  '1252': ['Normal'],
#  '1253': ['Normal'],
#  '1254': ['Glaucoma-present', 'svp-absent'],
#  '1255': ['Normal'],
#  '1256': ['Normal'],
#  '1257': ['Glaucoma-present', 'svp-absent'],
#  '1258': ['Normal'],
#  '1259': ['Glaucoma-present', 'svp-absent'],
#  '1260': ['Glaucoma-present', 'svp-absent'],
#  '1261': ['Normal'],
#  '1262': ['Normal'],
#  '1263': ['Normal'],
#  '1264': ['Normal'],
#  '1265': ['Glaucoma-present', 'svp-absent'],
#  '1266': ['Glaucoma-present', 'svp-absent'],
#  '1267': ['Normal'],
#  '1268': ['Normal'],
#  '1269': ['Glaucoma-present', 'svp-absent'],
#  '1270': ['Normal'],
#  '1271': ['Normal'],
#  '1272': ['Normal'],
#  '1273': ['Glaucoma-present', 'svp-absent'],
#  '0009': ['Normal'],
#  '0010': ['Normal'],
#  '0011': ['Normal'],
#  '0012': ['Glaucoma-present', 'svp-absent'],
#  '0015': ['Glaucoma-present', 'svp-absent'],
#  '0016': ['Normal'],
#  '0019': ['Normal'],
#  '0020': ['Normal'],
#  '0022': ['Normal'],
#  '0024': ['Glaucoma-present', 'svp-absent'],
#  '0026': ['Glaucoma-present', 'svp-absent'],
#  '0027': ['Normal'],
#  '0028': ['Normal'],
#  '0030': ['Glaucoma-present', 'svp-absent'],
#  '0032': ['Normal'],
#  '0034': ['Glaucoma-present', 'svp-absent'],
#  '0035': ['Glaucoma-present', 'svp-absent'],
#  '0036': ['Glaucoma-present', 'svp-absent'],
#  '0037': ['Glaucoma-present', 'svp-absent'],
#  '0038': ['Glaucoma-present', 'svp-absent'],
#  '0040': ['Glaucoma-present', 'svp-absent'],
#  '0042': ['Glaucoma-present', 'svp-absent'],
#  '0043': ['Glaucoma-present', 'svp-absent'],
#  '0044': ['Glaucoma-present', 'svp-absent'],
#  '0046': ['Glaucoma-present', 'svp-absent'],
#  '0048': ['Normal'],
#  '0050': ['Normal'],
#  '0051': ['Normal'],
#  '0052': ['Normal'],
#  '0054': ['Normal'],
#  '0055': ['Normal'],
#  '0056': ['Normal'],
#  '0057': ['Normal'],
#  '0058': ['Normal'],
#  '0059': ['Normal'],
#  '0060': ['Normal'],
#  '0062': ['Normal'],
#  '0064': ['Normal'],
#  '0065': ['Normal'],
#  '0066': ['Normal'],
#  '0075': ['Glaucoma-present', 'svp-absent'],
#  '0076': ['Glaucoma-present', 'svp-absent'],
#  '0085': ['Glaucoma-present', 'svp-absent'],
#  '0087': ['Glaucoma-present', 'svp-absent'],
#  '0091': ['Normal'],
#  '0101': ['Glaucoma-present', 'svp-absent'],
#  '0102': ['Glaucoma-present', 'svp-absent'],
#  '0103': ['Glaucoma-present', 'svp-absent'],
#  '0115': ['Glaucoma-present', 'svp-absent'],
#  '0142': ['Glaucoma-present', 'svp-absent'],
#  '0145': ['Glaucoma-present', 'svp-absent'],
#  '0147': ['Normal'],
#  '0149': ['Normal'],
#  '0151': ['Normal'],
#  '0155': ['Glaucoma-present', 'svp-absent'],
#  '0157': ['Normal'],
#  '0161': ['Normal'],
#  '0165': ['Normal'],
#  '0167': ['Normal'],
#  '0169': ['Normal'],
#  '0175': ['Normal'],
#  '0176': ['Normal'],
#  '0177': ['Glaucoma-present', 'svp-absent'],
#  '0178': ['Normal'],
#  '0179': ['Normal'],
#  '0180': ['Normal'],
#  '0181': ['Normal'],
#  '0182': ['Normal'],
#  '0183': ['Glaucoma-present', 'svp-absent'],
#  '0186': ['Normal'],
#  '0187': ['Glaucoma-present', 'svp-absent'],
#  '0188': ['Glaucoma-present', 'svp-absent'],
#  '0190': ['Glaucoma-present', 'svp-absent'],
#  '0192': ['Glaucoma-present', 'svp-absent'],
#  '0193': ['Normal'],
#  '0194': ['Glaucoma-present', 'svp-absent'],
#  '0196': ['Normal'],
#  '0197': ['Glaucoma-present', 'svp-absent'],
#  '0198': ['Normal'],
#  '0199': ['Normal'],
#  '0200': ['Normal'],
#  '0202': ['Normal'],
#  '0203': ['Normal'],
#  '0204': ['Normal'],
#  '0206': ['Normal'],
#  '0208': ['Normal'],
#  '0211': ['Normal'],
#  '0213': ['Glaucoma-present', 'svp-absent'],
#  '0215': ['Normal'],
#  '0217': ['Normal'],
#  '0219': ['Normal'],
#  '0221': ['Glaucoma-present', 'svp-absent'],
#  '0224': ['Normal'],
#  '0226': ['Normal'],
#  '0228': ['Normal'],
#  '0230': ['Normal'],
#  '0231': ['Glaucoma-present', 'svp-absent'],
#  '0233': ['Glaucoma-present', 'svp-absent'],
#  '0235': ['Normal'],
#  '0236': ['Glaucoma-present', 'svp-absent'],
#  '0237': ['Glaucoma-present', 'svp-absent'],
#  '0238': ['Glaucoma-present', 'svp-absent'],
#  '0239': ['Glaucoma-present', 'svp-absent'],
#  '0240': ['Glaucoma-present', 'svp-absent'],
#  '0241': ['Normal'],
#  '0242': ['Normal'],
#  '0243': ['Glaucoma-present', 'svp-absent'],
#  '0245': ['Normal'],
#  '0247': ['Normal'],
#  '0250': ['Normal'],
#  '0252': ['Normal'],
#  '0253': ['Normal'],
#  '0255': ['Glaucoma-present', 'svp-absent'],
#  '0257': ['Glaucoma-present', 'svp-absent'],
#  '0259': ['Glaucoma-present', 'svp-absent'],
#  '0261': ['Normal'],
#  '0262': ['Glaucoma-present', 'svp-absent'],
#  '0264': ['Normal'],
#  '0266': ['Glaucoma-present', 'svp-absent'],
#  '0268': ['Normal'],
#  '0270': ['Normal'],
#  '0272': ['Glaucoma-present', 'svp-absent'],
#  '0275': ['Normal'],
#  '0276': ['Normal'],
#  '0277': ['Normal'],
#  '0278': ['Normal'],
#  '0279': ['Glaucoma-present', 'svp-absent'],
#  '0281': ['Normal'],
#  '0294': ['Normal'],
#  '0295': ['Glaucoma-present', 'svp-absent'],
#  '0296': ['Glaucoma-present', 'svp-absent'],
#  '0299': ['Normal'],
#  '0302': ['Normal'],
#  '0303': ['Normal'],
#  '0319': ['Glaucoma-present', 'svp-absent'],
#  '0320': ['Glaucoma-present', 'svp-absent'],
#  '0321': ['Normal'],
#  '0322': ['Normal'],
#  '0323': ['Normal'],
#  '0326': ['Glaucoma-present', 'svp-absent'],
#  '0327': ['Glaucoma-present', 'svp-absent'],
#  '0330': ['Glaucoma-present', 'svp-absent'],
#  '0335': ['Glaucoma-present', 'svp-absent'],
#  '0337': ['Normal'],
#  '0344': ['Glaucoma-present', 'svp-absent'],
#  '1274': ['Normal'],
#  '1275': ['Normal'],
#  '1276': ['Normal'],
#  '1277': ['Normal'],
#  '1278': ['Normal'],
#  '1279': ['Normal'],
#  '1280': ['Glaucoma-present', 'svp-absent'],
#  '1281': ['Normal'],
#  '1282': ['Normal'],
#  '1283': ['Normal']}

# %%
# Temporal Localization
with open(temporal_localization_path, 'r') as f:
    temporal_localization = json.load(f)
temporal_localization
# Out:
# {'0002.avi': {'Num_frames': 334,
#   'temporal_localization': [[18, 34], [71, 334]]},
#  '0005.avi': {'Num_frames': 302,
#   'temporal_localization': [[0, 191], [192, 302]]},
#  '0009.avi': {'Num_frames': 299,
#   'temporal_localization': [[47, 74], [87, 299]]},
#  '0010.avi': {'Num_frames': 240, 'temporal_localization': [[0, 240]]},
#  '0011.avi': {'Num_frames': 297, 'temporal_localization': [[27, 194]]},
#  '0013.avi': {'Num_frames': 129, 'temporal_localization': [[7, 111]]},
#  '0014.avi': {'Num_frames': 328, 'temporal_localization': [[0, 308]]},
#  '0016.avi': {'Num_frames': 254, 'temporal_localization': [[0, 254]]},
#  '0019.avi': {'Num_frames': 260, 'temporal_localization': [[49, 252]]},
#  '0020.avi': {'Num_frames': 312, 'temporal_localization': [[0, 293]]},
#  '0022.avi': {'Num_frames': 255, 'temporal_localization': [[5, 247]]},
#  '0023.avi': {'Num_frames': 238, 'temporal_localization': [[23, 235]]},
#  '0025.avi': {'Num_frames': 268, 'temporal_localization': [[0, 256]]},
#  '0027.avi': {'Num_frames': 309,
#   'temporal_localization': [[0, 99], [128, 302]]},
#  '0028.avi': {'Num_frames': 307, 'temporal_localization': [[76, 307]]},
#  '0031.avi': {'Num_frames': 264, 'temporal_localization': [[20, 264]]},
#  '0032.avi': {'Num_frames': 239, 'temporal_localization': [[207, 239]]},
#  '0039.avi': {'Num_frames': 252,
#   'temporal_localization': [[20, 137], [142, 252]]},
#  '0041.avi': {'Num_frames': 262, 'temporal_localization': [[0, 227]]},
#  '0048.avi': {'Num_frames': 249, 'temporal_localization': [[0, 249]]},
#  '0050.avi': {'Num_frames': 320,
#   'temporal_localization': [[0, 26], [55, 84], [150, 217], [268, 296]]},
#  '0051.avi': {'Num_frames': 337, 'temporal_localization': [[0, 337]]},
#  '0052.avi': {'Num_frames': 260, 'temporal_localization': [[19, 236]]},
#  '0054.avi': {'Num_frames': 239, 'temporal_localization': [[0, 123]]},
#  '0055.avi': {'Num_frames': 298, 'temporal_localization': [[8, 280]]},
#  '0056.avi': {'Num_frames': 232, 'temporal_localization': [[27, 232]]},
#  '0057.avi': {'Num_frames': 303, 'temporal_localization': [[29, 296]]},
#  '0058.avi': {'Num_frames': 273, 'temporal_localization': [[1, 261]]},
#  '0059.avi': {'Num_frames': 271,
#   'temporal_localization': [[29, 59], [91, 110], [152, 241]]},
#  '0060.avi': {'Num_frames': 244,
#   'temporal_localization': [[18, 136], [170, 229]]},
#  '0062.avi': {'Num_frames': 261,
#   'temporal_localization': [[0, 155], [210, 244]]},
#  '0064.avi': {'Num_frames': 465,
#   'temporal_localization': [[13, 110], [193, 439]]},
#  '0065.avi': {'Num_frames': 238, 'temporal_localization': [[4, 226]]},
#  '0066.avi': {'Num_frames': 283, 'temporal_localization': [[2, 281]]},
#  '0067.avi': {'Num_frames': 318, 'temporal_localization': [[64, 301]]},
#  '0071.avi': {'Num_frames': 334, 'temporal_localization': [[25, 322]]},
#  '0072.avi': {'Num_frames': 379,
#   'temporal_localization': [[31, 96], [128, 357]]},
#  '0074.avi': {'Num_frames': 259, 'temporal_localization': [[103, 234]]},
#  '0077.avi': {'Num_frames': 380, 'temporal_localization': [[156, 368]]},
#  '0079.avi': {'Num_frames': 283, 'temporal_localization': [[27, 283]]},
#  '0080.avi': {'Num_frames': 265, 'temporal_localization': [[5, 265]]},
#  '0081.avi': {'Num_frames': 388,
#   'temporal_localization': [[185, 305], [306, 388]]},
#  '0084.avi': {'Num_frames': 280, 'temporal_localization': [[99, 280]]},
#  '0091.avi': {'Num_frames': 283, 'temporal_localization': [[14, 258]]},
#  '0092.avi': {'Num_frames': 346,
#   'temporal_localization': [[88, 120], [157, 335]]},
#  '0093.avi': {'Num_frames': 316,
#   'temporal_localization': [[0, 25], [109, 316]]},
#  '0094.avi': {'Num_frames': 361,
#   'temporal_localization': [[109, 135], [139, 337]]},
#  '0096.avi': {'Num_frames': 325,
#   'temporal_localization': [[17, 37], [83, 325]]},
#  '0097.avi': {'Num_frames': 243, 'temporal_localization': [[6, 235]]},
#  '0098.avi': {'Num_frames': 279, 'temporal_localization': [[37, 279]]},
#  '0099.avi': {'Num_frames': 294,
#   'temporal_localization': [[5, 45], [196, 284]]},
#  '0100.avi': {'Num_frames': 332, 'temporal_localization': [[60, 332]]},
#  '0105.avi': {'Num_frames': 317, 'temporal_localization': [[0, 296]]},
#  '0106.avi': {'Num_frames': 343, 'temporal_localization': [[60, 343]]},
#  '0107.avi': {'Num_frames': 299, 'temporal_localization': [[12, 224]]},
#  '0108.avi': {'Num_frames': 277, 'temporal_localization': [[62, 253]]},
#  '0109.avi': {'Num_frames': 334, 'temporal_localization': [[28, 334]]},
#  '0110.avi': {'Num_frames': 421,
#   'temporal_localization': [[33, 58], [102, 144], [166, 319], [343, 416]]},
#  '0112.avi': {'Num_frames': 341, 'temporal_localization': [[20, 341]]},
#  '0113.avi': {'Num_frames': 293, 'temporal_localization': [[155, 293]]},
#  '0114.avi': {'Num_frames': 287, 'temporal_localization': [[58, 287]]},
#  '0120.avi': {'Num_frames': 265, 'temporal_localization': [[5, 243]]},
#  '0121.avi': {'Num_frames': 271, 'temporal_localization': [[10, 246]]},
#  '0122.avi': {'Num_frames': 384, 'temporal_localization': [[52, 377]]},
#  '0123.avi': {'Num_frames': 400, 'temporal_localization': [[44, 400]]},
#  '0124.avi': {'Num_frames': 297, 'temporal_localization': [[16, 285]]},
#  '0125.avi': {'Num_frames': 304, 'temporal_localization': [[71, 285]]},
#  '0126.avi': {'Num_frames': 269, 'temporal_localization': [[8, 257]]},
#  '0128.avi': {'Num_frames': 283, 'temporal_localization': [[14, 281]]},
#  '0130.avi': {'Num_frames': 351, 'temporal_localization': [[97, 340]]},
#  '0133.avi': {'Num_frames': 273, 'temporal_localization': [[20, 262]]},
#  '0134.avi': {'Num_frames': 409, 'temporal_localization': [[30, 408]]},
#  '0135.avi': {'Num_frames': 298,
#   'temporal_localization': [[22, 199], [215, 276]]},
#  '0136.avi': {'Num_frames': 333,
#   'temporal_localization': [[37, 193], [193, 326]]},
#  '0138.avi': {'Num_frames': 289, 'temporal_localization': [[12, 289]]},
#  '0139.avi': {'Num_frames': 258, 'temporal_localization': [[22, 245]]},
#  '0140.avi': {'Num_frames': 324,
#   'temporal_localization': [[24, 59], [95, 306]]},
#  '0141.avi': {'Num_frames': 271, 'temporal_localization': [[35, 271]]},
#  '0147.avi': {'Num_frames': 397, 'temporal_localization': [[143, 370]]},
#  '0149.avi': {'Num_frames': 253, 'temporal_localization': [[0, 243]]},
#  '0150.avi': {'Num_frames': 253, 'temporal_localization': [[23, 231]]},
#  '0151.avi': {'Num_frames': 283, 'temporal_localization': [[2, 282]]},
#  '0152.avi': {'Num_frames': 288,
#   'temporal_localization': [[15, 46], [71, 288]]},
#  '0153.avi': {'Num_frames': 274, 'temporal_localization': [[162, 274]]},
#  '0157.avi': {'Num_frames': 255, 'temporal_localization': [[7, 255]]},
#  '0158.avi': {'Num_frames': 270, 'temporal_localization': [[0, 270]]},
#  '0159.avi': {'Num_frames': 302, 'temporal_localization': [[0, 256]]},
#  '0160.avi': {'Num_frames': 387, 'temporal_localization': [[25, 372]]},
#  '0161.avi': {'Num_frames': 311, 'temporal_localization': [[17, 275]]},
#  '0164.avi': {'Num_frames': 182, 'temporal_localization': [[10, 168]]},
#  '0165.avi': {'Num_frames': 242, 'temporal_localization': [[0, 231]]},
#  '0166.avi': {'Num_frames': 280, 'temporal_localization': [[41, 273]]},
#  '0167.avi': {'Num_frames': 270, 'temporal_localization': [[20, 265]]},
#  '0168.avi': {'Num_frames': 321, 'temporal_localization': [[9, 321]]},
#  '0169.avi': {'Num_frames': 264, 'temporal_localization': [[8, 254]]},
#  '0171.avi': {'Num_frames': 330, 'temporal_localization': [[103, 322]]},
#  '0172.avi': {'Num_frames': 258, 'temporal_localization': [[52, 258]]},
#  '0173.avi': {'Num_frames': 307, 'temporal_localization': [[42, 279]]},
#  '0174.avi': {'Num_frames': 233, 'temporal_localization': [[0, 224]]},
#  '0175.avi': {'Num_frames': 231, 'temporal_localization': [[10, 211]]},
#  '0176.avi': {'Num_frames': 282, 'temporal_localization': [[8, 280]]},
#  '0178.avi': {'Num_frames': 278, 'temporal_localization': [[0, 278]]},
#  '0179.avi': {'Num_frames': 292, 'temporal_localization': [[23, 291]]},
#  '0180.avi': {'Num_frames': 273, 'temporal_localization': [[23, 269]]},
#  '0181.avi': {'Num_frames': 254, 'temporal_localization': [[0, 238]]},
#  '0182.avi': {'Num_frames': 288, 'temporal_localization': [[24, 272]]},
#  '0184.avi': {'Num_frames': 236, 'temporal_localization': [[78, 219]]},
#  '0185.avi': {'Num_frames': 268, 'temporal_localization': [[26, 233]]},
#  '0186.avi': {'Num_frames': 282, 'temporal_localization': [[36, 267]]},
#  '0191.avi': {'Num_frames': 261, 'temporal_localization': [[28, 255]]},
#  '0193.avi': {'Num_frames': 211, 'temporal_localization': [[33, 209]]},
#  '0196.avi': {'Num_frames': 272, 'temporal_localization': [[0, 270]]},
#  '0198.avi': {'Num_frames': 262, 'temporal_localization': [[0, 247]]},
#  '0199.avi': {'Num_frames': 261, 'temporal_localization': [[20, 252]]},
#  '0200.avi': {'Num_frames': 293, 'temporal_localization': [[0, 286]]},
#  '0201.avi': {'Num_frames': 326, 'temporal_localization': [[17, 304]]},
#  '0202.avi': {'Num_frames': 358,
#   'temporal_localization': [[0, 72], [101, 135], [162, 331]]},
#  '0203.avi': {'Num_frames': 272, 'temporal_localization': [[15, 246]]},
#  '0204.avi': {'Num_frames': 311, 'temporal_localization': [[97, 296]]},
#  '0206.avi': {'Num_frames': 251, 'temporal_localization': [[36, 251]]},
#  '0207.avi': {'Num_frames': 268, 'temporal_localization': [[8, 268]]},
#  '0208.avi': {'Num_frames': 244, 'temporal_localization': [[13, 244]]},
#  '0210.avi': {'Num_frames': 299, 'temporal_localization': [[6, 288]]},
#  '0211.avi': {'Num_frames': 293, 'temporal_localization': [[0, 270]]},
#  '0214.avi': {'Num_frames': 272, 'temporal_localization': [[6, 257]]},
#  '0215.avi': {'Num_frames': 283, 'temporal_localization': [[17, 274]]},
#  '0216.avi': {'Num_frames': 250, 'temporal_localization': [[19, 250]]},
#  '0217.avi': {'Num_frames': 247, 'temporal_localization': [[20, 229]]},
#  '0218.avi': {'Num_frames': 196, 'temporal_localization': [[120, 196]]},
#  '0219.avi': {'Num_frames': 247, 'temporal_localization': [[55, 242]]},
#  '0223.avi': {'Num_frames': 241, 'temporal_localization': [[19, 241]]},
#  '0224.avi': {'Num_frames': 223, 'temporal_localization': [[27, 205]]},
#  '0225.avi': {'Num_frames': 293, 'temporal_localization': [[7, 293]]},
#  '0226.avi': {'Num_frames': 275, 'temporal_localization': [[3, 273]]},
#  '0227.avi': {'Num_frames': 269, 'temporal_localization': [[18, 256]]},
#  '0228.avi': {'Num_frames': 262, 'temporal_localization': [[12, 260]]},
#  '0229.avi': {'Num_frames': 344, 'temporal_localization': [[10, 336]]},
#  '0230.avi': {'Num_frames': 110, 'temporal_localization': [[9, 98]]},
#  '0234.avi': {'Num_frames': 344,
#   'temporal_localization': [[3, 87], [114, 329]]},
#  '0235.avi': {'Num_frames': 289,
#   'temporal_localization': [[19, 95], [99, 129], [153, 241], [265, 288]]},
#  '0241.avi': {'Num_frames': 317,
#   'temporal_localization': [[7, 54], [135, 317]]},
#  '0242.avi': {'Num_frames': 257, 'temporal_localization': [[48, 256]]},
#  '0244.avi': {'Num_frames': 269, 'temporal_localization': [[4, 254]]},
#  '0245.avi': {'Num_frames': 249, 'temporal_localization': [[3, 248]]},
#  '0246.avi': {'Num_frames': 217, 'temporal_localization': [[3, 211]]},
#  '0247.avi': {'Num_frames': 220, 'temporal_localization': [[18, 220]]},
#  '0249.avi': {'Num_frames': 259, 'temporal_localization': [[0, 256]]},
#  '0250.avi': {'Num_frames': 275, 'temporal_localization': [[13, 264]]},
#  '0252.avi': {'Num_frames': 250, 'temporal_localization': [[69, 233]]},
#  '0253.avi': {'Num_frames': 253, 'temporal_localization': [[99, 249]]},
#  '0256.avi': {'Num_frames': 188, 'temporal_localization': [[20, 180]]},
#  '0260.avi': {'Num_frames': 325, 'temporal_localization': [[14, 324]]},
#  '0261.avi': {'Num_frames': 321, 'temporal_localization': [[0, 304]]},
#  '0263.avi': {'Num_frames': 276, 'temporal_localization': [[83, 276]]},
#  '0264.avi': {'Num_frames': 282, 'temporal_localization': [[3, 270]]},
#  '0265.avi': {'Num_frames': 279, 'temporal_localization': [[17, 243]]},
#  '0267.avi': {'Num_frames': 206, 'temporal_localization': [[0, 129]]},
#  '0268.avi': {'Num_frames': 241, 'temporal_localization': [[0, 221]]},
#  '0269.avi': {'Num_frames': 253, 'temporal_localization': [[10, 250]]},
#  '0270.avi': {'Num_frames': 278, 'temporal_localization': [[13, 257]]},
#  '0271.avi': {'Num_frames': 178, 'temporal_localization': [[14, 178]]},
#  '0275.avi': {'Num_frames': 486,
#   'temporal_localization': [[0, 21],
#    [66, 92],
#    [225, 309],
#    [331, 442],
#    [466, 486]]},
#  '0276.avi': {'Num_frames': 91, 'temporal_localization': [[14, 91]]},
#  '0277.avi': {'Num_frames': 81, 'temporal_localization': [[7, 66]]},
#  '0278.avi': {'Num_frames': 547,
#   'temporal_localization': [[10, 219], [242, 373], [395, 484], [523, 546]]},
#  '0281.avi': {'Num_frames': 254, 'temporal_localization': [[23, 254]]},
#  '0285.avi': {'Num_frames': 409,
#   'temporal_localization': [[11, 37], [53, 81], [174, 399]]},
#  '0286.avi': {'Num_frames': 285,
#   'temporal_localization': [[4, 218], [246, 282]]},
#  '0290.avi': {'Num_frames': 273, 'temporal_localization': [[29, 273]]},
#  '0291.avi': {'Num_frames': 343, 'temporal_localization': [[19, 335]]},
#  '0292.avi': {'Num_frames': 30, 'temporal_localization': [[0, 30]]},
#  '0293.avi': {'Num_frames': 242, 'temporal_localization': [[22, 236]]},
#  '0294.avi': {'Num_frames': 282, 'temporal_localization': [[72, 270]]},
#  '0299.avi': {'Num_frames': 194, 'temporal_localization': [[31, 94]]},
#  '0302.avi': {'Num_frames': 251, 'temporal_localization': [[5, 251]]},
#  '0303.avi': {'Num_frames': 261, 'temporal_localization': [[9, 261]]},
#  '0304.avi': {'Num_frames': 263, 'temporal_localization': [[20, 263]]},
#  '0305.avi': {'Num_frames': 243, 'temporal_localization': [[14, 240]]},
#  '0307.avi': {'Num_frames': 405, 'temporal_localization': [[26, 394]]},
#  '0308.avi': {'Num_frames': 209, 'temporal_localization': [[0, 209]]},
#  '0309.avi': {'Num_frames': 655, 'temporal_localization': [[9, 645]]},
#  '0310.avi': {'Num_frames': 570, 'temporal_localization': [[35, 553]]},
#  '0312.avi': {'Num_frames': 1013,
#   'temporal_localization': [[383, 644], [661, 865], [873, 913], [939, 963]]},
#  '0314.avi': {'Num_frames': 318, 'temporal_localization': [[0, 318]]},
#  '0317.avi': {'Num_frames': 341, 'temporal_localization': [[17, 341]]},
#  '0318.avi': {'Num_frames': 428, 'temporal_localization': [[0, 420]]},
#  '0321.avi': {'Num_frames': 335, 'temporal_localization': [[24, 331]]},
#  '0322.avi': {'Num_frames': 297, 'temporal_localization': [[0, 286]]},
#  '0323.avi': {'Num_frames': 400,
#   'temporal_localization': [[24, 98], [113, 152], [186, 236], [324, 362]]},
#  '0328.avi': {'Num_frames': 232, 'temporal_localization': [[15, 213]]},
#  '0329.avi': {'Num_frames': 304,
#   'temporal_localization': [[10, 35], [42, 281]]},
#  '0331.avi': {'Num_frames': 120, 'temporal_localization': [[11, 120]]},
#  '0332.avi': {'Num_frames': 243, 'temporal_localization': [[0, 229]]},
#  '0336.avi': {'Num_frames': 222, 'temporal_localization': [[4, 222]]},
#  '0337.avi': {'Num_frames': 244, 'temporal_localization': [[18, 244]]},
#  '0341.avi': {'Num_frames': 243, 'temporal_localization': [[17, 242]]},
#  '0342.avi': {'Num_frames': 340, 'temporal_localization': [[130, 318]]},
#  '0354.avi': {'Num_frames': 272,
#   'temporal_localization': [[0, 68], [72, 249]]},
#  '0355.avi': {'Num_frames': 274, 'temporal_localization': [[10, 241]]},
#  '0357.avi': {'Num_frames': 272, 'temporal_localization': [[48, 258]]},
#  '0359.avi': {'Num_frames': 236, 'temporal_localization': [[4, 227]]},
#  '1007.avi': {'Num_frames': 67, 'temporal_localization': [[1, 53]]},
#  '1009.avi': {'Num_frames': 100, 'temporal_localization': [[5, 85]]},
#  '1011.avi': {'Num_frames': 265,
#   'temporal_localization': [[12, 149], [149, 256]]},
#  '1012.avi': {'Num_frames': 145, 'temporal_localization': [[7, 145]]},
#  '1018.avi': {'Num_frames': 188, 'temporal_localization': [[4, 179]]},
#  '1021.avi': {'Num_frames': 160, 'temporal_localization': [[12, 158]]},
#  '1022.avi': {'Num_frames': 214, 'temporal_localization': [[124, 187]]},
#  '1030.avi': {'Num_frames': 499,
#   'temporal_localization': [[20, 267], [294, 492]]},
#  '1034.avi': {'Num_frames': 137, 'temporal_localization': [[0, 137]]},
#  '1043.avi': {'Num_frames': 257, 'temporal_localization': [[26, 238]]},
#  '1046.avi': {'Num_frames': 190, 'temporal_localization': [[10, 190]]},
#  '1050.avi': {'Num_frames': 117, 'temporal_localization': [[7, 79]]},
#  '1060.avi': {'Num_frames': 328, 'temporal_localization': [[0, 328]]},
#  '1062.avi': {'Num_frames': 65, 'temporal_localization': [[8, 65]]},
#  '1064.avi': {'Num_frames': 112, 'temporal_localization': [[9, 98]]},
#  '1065.avi': {'Num_frames': 255, 'temporal_localization': [[3, 248]]},
#  '1067.avi': {'Num_frames': 68, 'temporal_localization': [[16, 50]]},
#  '1069.avi': {'Num_frames': 133, 'temporal_localization': [[16, 124]]},
#  '1070.avi': {'Num_frames': 180,
#   'temporal_localization': [[30, 81], [100, 159]]},
#  '1071.avi': {'Num_frames': 262, 'temporal_localization': [[10, 262]]},
#  '1074.avi': {'Num_frames': 318,
#   'temporal_localization': [[17, 182], [182, 318]]},
#  '1075.avi': {'Num_frames': 88, 'temporal_localization': [[13, 80]]},
#  '1081.avi': {'Num_frames': 337,
#   'temporal_localization': [[18, 40], [62, 111], [204, 229]]},
#  '1084.avi': {'Num_frames': 127, 'temporal_localization': [[4, 127]]},
#  '1085.avi': {'Num_frames': 240, 'temporal_localization': [[20, 225]]},
#  '1086.avi': {'Num_frames': 342,
#   'temporal_localization': [[0, 25],
#    [52, 84],
#    [107, 190],
#    [199, 286],
#    [307, 338]]},
#  '1088.avi': {'Num_frames': 440, 'temporal_localization': [[0, 412]]},
#  '1089.avi': {'Num_frames': 149,
#   'temporal_localization': [[11, 67], [71, 97]]},
#  '1093.avi': {'Num_frames': 174, 'temporal_localization': [[22, 172]]},
#  '1094.avi': {'Num_frames': 313, 'temporal_localization': [[2, 312]]},
#  '1095.avi': {'Num_frames': 195,
#   'temporal_localization': [[0, 95], [125, 183]]},
#  '1101.avi': {'Num_frames': 151, 'temporal_localization': [[58, 84]]},
#  '1102.avi': {'Num_frames': 330, 'temporal_localization': [[46, 98]]},
#  '1105.avi': {'Num_frames': 259,
#   'temporal_localization': [[8, 152], [168, 246]]},
#  '1106.avi': {'Num_frames': 97, 'temporal_localization': [[0, 97]]},
#  '1113.avi': {'Num_frames': 182, 'temporal_localization': [[9, 164]]},
#  '1122.avi': {'Num_frames': 140, 'temporal_localization': [[15, 140]]},
#  '1123.avi': {'Num_frames': 250,
#   'temporal_localization': [[27, 67], [112, 224]]},
#  '1127.avi': {'Num_frames': 109, 'temporal_localization': [[18, 101]]},
#  '1132.avi': {'Num_frames': 160,
#   'temporal_localization': [[39, 86], [127, 157]]},
#  '1135.avi': {'Num_frames': 118, 'temporal_localization': [[15, 112]]},
#  '1137.avi': {'Num_frames': 92, 'temporal_localization': [[17, 74]]},
#  '1140.avi': {'Num_frames': 95, 'temporal_localization': [[5, 88]]},
#  '1141.avi': {'Num_frames': 114, 'temporal_localization': [[4, 96]]},
#  '1143.avi': {'Num_frames': 67, 'temporal_localization': [[14, 54]]},
#  '1144.avi': {'Num_frames': 65, 'temporal_localization': [[10, 44]]},
#  '1149.avi': {'Num_frames': 163, 'temporal_localization': [[0, 120]]},
#  '1151.avi': {'Num_frames': 60, 'temporal_localization': [[9, 53]]},
#  '1152.avi': {'Num_frames': 178,
#   'temporal_localization': [[11, 35], [52, 111], [124, 178]]},
#  '1157.avi': {'Num_frames': 61, 'temporal_localization': [[17, 43]]},
#  '1158.avi': {'Num_frames': 289,
#   'temporal_localization': [[0, 153], [173, 289]]},
#  '1160.avi': {'Num_frames': 116,
#   'temporal_localization': [[0, 61], [61, 103]]},
#  '1161.avi': {'Num_frames': 38, 'temporal_localization': [[0, 30]]},
#  '1163.avi': {'Num_frames': 83, 'temporal_localization': [[25, 76]]},
#  '1165.avi': {'Num_frames': 159, 'temporal_localization': [[17, 159]]},
#  '1167.avi': {'Num_frames': 55, 'temporal_localization': [[19, 50]]},
#  '1168.avi': {'Num_frames': 361, 'temporal_localization': [[15, 338]]},
#  '1169.avi': {'Num_frames': 54, 'temporal_localization': [[15, 45]]},
#  '1170.avi': {'Num_frames': 88, 'temporal_localization': [[25, 81]]},
#  '1171.avi': {'Num_frames': 49, 'temporal_localization': [[11, 47]]},
#  '1174.avi': {'Num_frames': 116, 'temporal_localization': [[11, 81]]},
#  '1178.avi': {'Num_frames': 167,
#   'temporal_localization': [[18, 98], [99, 159]]},
#  '1179.avi': {'Num_frames': 73, 'temporal_localization': [[11, 60]]},
#  '1180.avi': {'Num_frames': 232, 'temporal_localization': [[9, 217]]},
#  '1183.avi': {'Num_frames': 165, 'temporal_localization': [[5, 165]]},
#  '1184.avi': {'Num_frames': 233, 'temporal_localization': [[12, 223]]},
#  '1185.avi': {'Num_frames': 28, 'temporal_localization': [[0, 24]]},
#  '1186.avi': {'Num_frames': 81, 'temporal_localization': [[10, 37]]},
#  '1188.avi': {'Num_frames': 79, 'temporal_localization': [[10, 64]]},
#  '1190.avi': {'Num_frames': 68, 'temporal_localization': [[0, 57]]},
#  '1191.avi': {'Num_frames': 81, 'temporal_localization': [[20, 49]]},
#  '1193.avi': {'Num_frames': 101, 'temporal_localization': [[0, 77]]},
#  '1197.avi': {'Num_frames': 81, 'temporal_localization': [[15, 70]]},
#  '1198.avi': {'Num_frames': 88, 'temporal_localization': [[6, 78]]},
#  '1199.avi': {'Num_frames': 113, 'temporal_localization': [[1, 96]]},
#  '1200.avi': {'Num_frames': 121, 'temporal_localization': [[17, 109]]},
#  '1204.avi': {'Num_frames': 67, 'temporal_localization': [[17, 60]]},
#  '1205.avi': {'Num_frames': 200, 'temporal_localization': [[11, 194]]},
#  '1206.avi': {'Num_frames': 187, 'temporal_localization': [[10, 144]]},
#  '1207.avi': {'Num_frames': 96, 'temporal_localization': [[27, 95]]},
#  '1211.avi': {'Num_frames': 104,
#   'temporal_localization': [[0, 30], [30, 100]]},
#  '1212.avi': {'Num_frames': 56, 'temporal_localization': [[16, 44]]},
#  '1213.avi': {'Num_frames': 126, 'temporal_localization': [[11, 85]]},
#  '1214.avi': {'Num_frames': 80, 'temporal_localization': [[19, 73]]},
#  '1215.avi': {'Num_frames': 171, 'temporal_localization': [[11, 170]]},
#  '1216.avi': {'Num_frames': 205, 'temporal_localization': [[104, 171]]},
#  '1217.avi': {'Num_frames': 74, 'temporal_localization': [[19, 50]]},
#  '1218.avi': {'Num_frames': 93, 'temporal_localization': [[16, 76]]},
#  '1219.avi': {'Num_frames': 130,
#   'temporal_localization': [[12, 39], [64, 119]]},
#  '1223.avi': {'Num_frames': 139, 'temporal_localization': [[0, 139]]},
#  '1225.avi': {'Num_frames': 111, 'temporal_localization': [[8, 101]]},
#  '1226.avi': {'Num_frames': 244,
#   'temporal_localization': [[9, 94], [95, 162], [165, 232]]},
#  '1228.avi': {'Num_frames': 165, 'temporal_localization': [[11, 152]]},
#  '1229.avi': {'Num_frames': 129, 'temporal_localization': [[0, 117]]},
#  '1232.avi': {'Num_frames': 163,
#   'temporal_localization': [[8, 62], [81, 155]]},
#  '1233.avi': {'Num_frames': 65, 'temporal_localization': [[13, 55]]},
#  '1235.avi': {'Num_frames': 117, 'temporal_localization': [[4, 89]]},
#  '1244.avi': {'Num_frames': 211, 'temporal_localization': [[10, 211]]},
#  '1248.avi': {'Num_frames': 76, 'temporal_localization': [[0, 67]]},
#  '1249.avi': {'Num_frames': 97, 'temporal_localization': [[0, 97]]},
#  '1250.avi': {'Num_frames': 65, 'temporal_localization': [[0, 65]]},
#  '1252.avi': {'Num_frames': 48, 'temporal_localization': [[11, 31]]},
#  '1253.avi': {'Num_frames': 72, 'temporal_localization': [[4, 71]]},
#  '1255.avi': {'Num_frames': 86, 'temporal_localization': [[0, 78]]},
#  '1256.avi': {'Num_frames': 83, 'temporal_localization': [[13, 72]]},
#  '1258.avi': {'Num_frames': 48, 'temporal_localization': [[13, 38]]},
#  '1261.avi': {'Num_frames': 131, 'temporal_localization': [[16, 79]]},
#  '1262.avi': {'Num_frames': 84, 'temporal_localization': [[48, 84]]},
#  '1267.avi': {'Num_frames': 88, 'temporal_localization': [[5, 86]]},
#  '1271.avi': {'Num_frames': 75, 'temporal_localization': [[16, 62]]},
#  '1272.avi': {'Num_frames': 72, 'temporal_localization': [[23, 67]]},
#  '1274.avi': {'Num_frames': 105, 'temporal_localization': [[2, 105]]},
#  '1275.avi': {'Num_frames': 110, 'temporal_localization': [[0, 110]]},
#  '1276.avi': {'Num_frames': 78, 'temporal_localization': [[0, 75]]},
#  '1277.avi': {'Num_frames': 136, 'temporal_localization': [[19, 131]]},
#  '1278.avi': {'Num_frames': 32, 'temporal_localization': [[0, 23]]},
#  '1279.avi': {'Num_frames': 69, 'temporal_localization': [[8, 54]]},
#  '1281.avi': {'Num_frames': 78, 'temporal_localization': [[12, 78]]},
#  '1282.avi': {'Num_frames': 120, 'temporal_localization': [[12, 105]]},
#  '1283.avi': {'Num_frames': 53, 'temporal_localization': [[0, 48]]},
#  '1125.avi': {'Num_frames': 86, 'temporal_localization': [[0, 86]]},
#  '1189.avi': {'Num_frames': 79, 'temporal_localization': [[1, 79]]},
#  '1059.avi': {'Num_frames': 25, 'temporal_localization': [[0, 25]]},
#  '1268.avi': {'Num_frames': 51, 'temporal_localization': [[10, 51]]},
#  '1092.avi': {'Num_frames': 40, 'temporal_localization': [[6, 28]]},
#  '1066.avi': {'Num_frames': 53, 'temporal_localization': [[0, 52]]},
#  '0346.avi': {'Num_frames': 267, 'temporal_localization': [[181, 193]]},
#  '0361.avi': {'Num_frames': 257,
#   'temporal_localization': [[65, 93], [163, 256]]},
#  '1096.avi': {'Num_frames': 149, 'temporal_localization': [[75, 148]]},
#  '1201.avi': {'Num_frames': 53, 'temporal_localization': [[12, 52]]},
#  '0353.avi': {'Num_frames': 260, 'temporal_localization': [[0, 259]]},
#  '1054.avi': {'Num_frames': 135, 'temporal_localization': [[0, 134]]},
#  '1156.avi': {'Num_frames': 18, 'temporal_localization': [[0, 17]]},
#  '1162.avi': {'Num_frames': 35, 'temporal_localization': [[0, 34]]}}

# %%
# Image and mask files
peak_trough_image_dir = r"C:\Users\gabe7\Downloads\Fundus_Dataset\Labels\Temporal\Peak_and_trough\images"
peak_trough_mask_dir = r"C:\Users\gabe7\Downloads\Fundus_Dataset\Labels\Temporal\Peak_and_trough\masks"

# %%
# Load training JSON
with open(training_path, 'r') as f:
    train_dict = json.load(f)
len(train_dict)
# Out:
# 485

# %%
# Load validation JSON
with open(validation_path, 'r') as f:
    val_dict = json.load(f)
len(val_dict)
# Out:
# 32

# %%
# Load testing JSON
with open(testing_path, 'r') as f:
    test_dict = json.load(f)
len(test_dict)
# Out:
# 118

# %%
# Load metadata JSON
with open(peak_trough_metadata_path, 'r') as f:
    peak_trough_metadata = json.load(f)

# %%
len(peak_trough_metadata)
# Out:
# 335

# %% [markdown]
# # Train Validation Test Split

# %%
# Retrieve ID's from pre split
training_ids = train_dict.keys()
validation_ids = val_dict.keys()
testing_ids = test_dict.keys()

# %%
# Retrieve each training sample only if there is ID match
training_samples = []
for id, value in peak_trough_metadata.items():
    if id in training_ids:
        training_samples.append(value)
len(training_samples)
# Out:
# 254

# %%
# Retrieve each validation sample only if there is ID match
validation_samples = []
for id, value in peak_trough_metadata.items():
    if id in validation_ids:
        validation_samples.append(value)
len(validation_samples)
# Out:
# 13

# %%
# Retrieve each testing sample only if there is ID match
testing_samples = []
for id, value in peak_trough_metadata.items():
    if id in testing_ids:
        testing_samples.append(value)
len(testing_samples)
# Out:
# 68

# %%
len(val_dict)
# Out:
# 32

# %% [markdown]
# **Segmentation sample splits should be in format:**
#
# {
#
# 'Video Title': Video Title ('0001.avi')
#
# 'Image': Image File Path,
#
# 'Mask': Mask FIle Path,
#
# }
#
# **Temporal Localization sample splits should be in format:**
#
# {
#
# 'Video Title': Video Title ('0001.avi')
#
# 'Video': Video File Path,
#
# 'Start, End': [Start frame, end frame],
#
# 'Num_frames': Number of frames
#
# }

# %% [markdown]
# **Base paths to join with metadata paths.**

# %%
base_frame_path = r"C:\Users\gabe7\Downloads\Fundus_Dataset\Labels"
base_mask_path = r"C:\Users\gabe7\Downloads\Fundus_Dataset\Labels"

# %% [markdown]
# **Example Image Path:**
# C:\Users\gabe7\Downloads\Fundus_Dataset\Labels\Temporal\Peak_and_trough\masks\0011_104_min.png
#
# **Example metadata path:**
# RVD/Temporal/Peak_and_trough/masks/0011_104_min.png
#
# - Need to remove 'RVD' from metadata path
# - Join metadata path with base path
# - Append to final dictionary for MONAI use

# %%
def prep_split(video_file_frame, video_file_mask, split):
    # Remove 'RVD'
        video_file_frame = video_file_frame.replace("RVD/", "", 1)
        video_file_mask = video_file_mask.replace("RVD/", "", 1)
        # Join base path and metadata path
        frame_path = os.path.join(base_frame_path, video_file_frame)
        mask_path = os.path.join(base_mask_path, video_file_mask)
        # Normalize path 
        frame_path = os.path.normpath(frame_path)
        mask_path = os.path.normpath(mask_path)
        # Extract Video Title and Min or Max:
        # Get just the filename
        filename = os.path.basename(frame_path)           
        name = os.path.splitext(filename)[0]           
        video_title, frame_number, min_max = name.split('_')
        # Get disease variety class
        disease = disease_variety[video_title]
        # Get SVP Classification
        svp_class = svp_classification[video_title + ".avi"]
        # Concantenate metdata
        metadata = {
            "Video Title": video_title,
            "Frame": frame_number, 
            "Min/Max": min_max,
            "Disease": disease,
            "SVP": svp_class
        }
        # Append in MONAI format
        split.append({
            "Image": frame_path,
            "Mask": mask_path,
            "Metadata": metadata
        })

# %% [markdown]
# **Training Split**

# %%
train = []
for seg_dict in training_samples:
    for video_file_frame, video_file_mask in seg_dict.items():
        prep_split(video_file_frame, video_file_mask, train)

# %% [markdown]
# **Validation Split**

# %%
validation = []
for seg_dict in validation_samples:
    for video_file_frame, video_file_mask in seg_dict.items():
        prep_split(video_file_frame, video_file_mask, validation)

# %% [markdown]
# **Testing Split**

# %%
test = []
for seg_dict in testing_samples:
    for video_file_frame, video_file_mask in seg_dict.items():
        prep_split(video_file_frame, video_file_mask, test)

# %% [markdown]
# **Save split file for transfer**

# %%
joblib.dump((train, validation, test), 'train_split.joblib')
# Out:
# ['train_split.joblib']
